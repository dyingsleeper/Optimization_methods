# %% [markdown]
# # <center>Лабораторная работа 4.</center>
#
# ## <center>Модели целочисленного программирования</center>
#
# *Автор материала: к.т.н., доцент кафедры Фундаметальной информатики и оптимального управления ВолГУ Михаил Алексеевич Харитонов*
#
# **Цель работы:** приобретение практических навыков решения задач целочисленного программирования c использованием языка Python в Jupyter Notebook.
#
# **Задание:** Заполните ответ в клетках (где написано "Ваш код здесь" или "Ваш ответ здесь"), ответьте на вопросы.

# %% [markdown]
# # Часть 1 Python

# %% [markdown]
# ##Задание 1

# %% [markdown]
# Логистическая компания имеет $m=5$ сбытовыx баз и $n=5$ заказов, которые необходимо доставить различным потребителям. Складские помещения каждой базы вполне достаточны для того, чтобы вместить один из этих заказов. В табл. 1 содержится информация о расстоянии между каждой базой и каждым потребителем.
#
# $$
# \begin{aligned}
# & \text {Таблица 1. Расстояние от сбытовых баз до потребителей }\\
# &\begin{array}{cccccc}
# \hline \hline \text {Сбытовая база } & \text{ $P_1$ }& \text{ $P_2$ }& \text{ $P_3$} & \text{ $P_4$  } & \text{ $P_5$  }\\\hline
# \text {$B_1$} & 50 & 83 & 97 & 23 & 70 \\
# \text {$B_2$} & 47 & 77 & 23 & 25 & 15\\
# \text {$B_3$} & 31 & 25 & 41 & 35 & 32 \\
# \text {$B_4$} & 35 & 144 & 56 & 31 & 45 \\
# \text {$B_5$} & 45 & 30 & 16 & 10 & 66 \\
# \hline
# \end{array}
# \end{aligned}
# $$
#
# Как следует распределить заказы по сбытовым базам, чтобы общая дальность транспортировки была минимальной?
#
# 1. Записать математическую постановку данной задачи в LaTeX.
# 2. Найти решение данной задачи с использованием соответствующего солвера

# %%
#Ваш код здесь

# %% [markdown]
# ##Задание 2

# %% [markdown]
# Найти решение данной задачи с использованием соответствующего солвера
# \begin{eqnarray*}
# f(x)=13 x_{11} + 120 x_{12}-21 x_{13} + 16 x_{14} + \\
# +13 x_{21} + 12 x_{22}+ 32 x_{23} + 7 x_{24} + \\
# +21 x_{31} + 2 x_{32}+ 7 x_{34} \to \max\limits_{G},\\
# G=\left\{ 12x_{11} + 3x_{12} + 8x_{13} + 6x_{14} \le 2900,\\
# 2x_{21} + 2x_{22} + 13x_{23} + x_{24} \le 4300, \\
# 6x_{31} - 12x_{32} + x_{33} + 9x_{34} \le 3501, \\
# x_{11} + x_{12} + x_{13} + x_{14} \le 2306,\\
# x_{21} + x_{22} + x_{23} + x_{24} \le 2600, \\
# x_{31} + x_{32} + x_{33} + x_{34} \le 3204, \\
# x_{ij} \ge 0, i=\overline{0,3} , j=\overline{0,4} ,\\
# x_{ij} \in Z, i=\overline{1,3} , j=\overline{2,4}\right\}
# \end{eqnarray*}

# %%
#Ваш код здесь

# %% [markdown]
# # Часть 2 Решение задач

# %% [markdown]
# 1.  Для строительства трех дорог используется гравий из четырех карьеров. Запасы гравия в каждом из карьеров соответственно равны 120, 280 и 160 уел. ед. Потребности в гравии для строительства каждой из дорог соответственно равны 130, 220, 60 и 70 уел. ед. Известны также тарифы перевозок 1 уел. ед. гравия из каждого из карьеров к каждой из строящихся дорог, которые задаются матрицей
#     \begin{equation*}
#   X=\left(
#      \begin{array}{ccccc}
#        1 & 7 & 9 & 5 \\
#        4 & 2 & 6 & 8  \\
#        3 & 8 & 1 & 2 \\
#      \end{array}
#    \right).
# \end{equation*}
#   а) Найти план перевозок гравия, при котором потребности в нем каждой из строящихся дорог были бы удовлетворены при наименьшей общей стоимости перевозок.
#
#   б) c помощью солвера проверить решение из пункта а)
#
# 2.
# На трех железнодорожных станциях $A_1$, $A_2$ и $A_3$ скопилось 120, 110 и 130 незагруженных вагонов. Эти вагоны необходимо перегнать на
#   железнодорожные станции $B_1$, $B_2$, $B_3$, $B_4$  и $B_5$. На каждой из этих станций потребность в вагонах соответственно равна 80, 60, 70,
#   100 и 50. Учитывая, что с железнодорожной станции $A_2$ не представляется возможным перегнать вагоны иа станцию $B_2$ и $B_4$, и зная, что    тарифы перегонки одного вагона определяются матрицей
#    \begin{equation*} C=\begin{pmatrix}
#       2 & 4 & 1 & 6 & 7 \\
#       3 & 3 & 5 & 4 & 2 \\
#        8 & 9 & 6 & 3 & 4 \\
#    \end{pmatrix}.\end{equation*}
#    а) Найти план доставки товаров, при котором общая стоимость перевозок является минимальной.
#
#    б) c помощью солвера проверить решение из пункта а)
#
#
#
# 3. На трех складах оптовой базы сосредоточена мука в количествах, равных соответственно 140, 360 и 180 т. Эту муку необходимо завезти в пять магазинов, каждый нз которых должен получить соответственно 90, 120, 230, 180 и 60 т. С 1-го склада муку не представляется возможным перевозить во 2-й и 5-й магазины, а из 2-го склада в 3-й магазин должно быть завезено 100 т. муки. Зная тарифы перевозки 1 т. муки с каждого из складов в соответствующие магазины, которые определяются матрицей
# $$C=\begin{pmatrix}
#       7 & - & 8 & 2 & - \\
#       4 & 3 & 1 & 5 & 6 \\
#        5 & 2 & 3 & 2 & 8 \\
#   \end{pmatrix}.$$
#     а) найти план перевозок, обеспечивающий минимальную общую стоимость перевозок.
#
#     б) c помощью солвера проверить решение из пункта а)
#
#
#
#
# 4. На работу устраиваются $n$ кандидатов на $n$ вакансий и они получили соответствующие оценки при собеседовании на каждую вакансию, провести набор кандидатов на шесть вакансий так, чтобы суммарная оценка кандидатов была максимальной. Запишите математическую постановку данной задачи.
#
# 5. Найти оптимальный план         транспортной задачи и с помощью солвера проверить решение
#
# $$
# \begin{aligned}
# &\begin{array}{|c|cccc|c|}
# \hline \hline \text {Пункты отправления} & \text{ $B_1$ }& \text{ $B_2$ }& \text{ $B_3$} & \text{ $B_4$  } & \text{ $B_5$  } & Запасы\\\hline
# \text {$A_1$} & 5 & 3 & 7 & 3 & 7 & 70\\
# \text {$A_2$} & 4 & 7 & 3 & 2 & 1 &110\\
# \text {$A_3$} & 3 & 2 & 4 & 3 & 2 &60\\
# \hline
# Потребности         &  40       &  30       &   30      &    70   & 40  \\ \hline
# \end{array}
# \end{aligned}
# $$
#
# 6. Найти оптимальный план         транспортной задачи и с помощью солвера проверить решение
#
# $$
# \begin{aligned}
# &\begin{array}{|c|cccc|c|}
# \hline \hline \text {Пункты отправления} & \text{ $B_1$ }& \text{ $B_2$ }& \text{ $B_3$} & \text{ $B_4$  } & \text{ $B_5$  } & Запасы\\\hline
# \text {$A_1$} & 15 & 13 & 7 & 3 & 7 & 70\\
# \text {$A_2$} & 14 & 17 & 3 & 2 & 1 &110\\
# \text {$A_3$} & 3 & 2 & 1 & 3 & 2 &60\\
# \hline
# Потребности         &  30       &  20       &   30      &    70   & 40  \\ \hline
# \end{array}
# \end{aligned}
# $$
#
#
#
# 7. Найдите оптимальное целочисленное
# решение задачи линейного программирования
# \begin{equation*}
# F=3x_{1} +x_{2} \to \max\limits_D
# \end{equation*}
# \begin{equation*} D =
# \left\{\begin{array}{c} {2x_{1} +3x_{2} \le 6} \\
#  {2x_{1} -3x_{2} \le 3} \\
#   {x_{1} \ge0, x_{2}\ge0,x_{1} ,x_{2} \in Z} \end{array}\right..
# \end{equation*}
#
# 8. Имеются $n$ предметов, которые необходимо поместить в рюкзак (ранец). Пусть известны вес $w_j$ и <<ценность>> $c_j$ каждого предмета ($j= 1,2,\ldots,n$). Требуется заполнить рюкзак, не превышая его грузоподъемности (объема) $V$ и максимизируя суммарную ценность груза.
# Входные данные $w = [5, 7, 1, 3, 4]$, $c = [14, 5, 3, 6, 5]$, $V = 15$.

# %% [markdown]
# # Часть 3 Теория

# %% [markdown]
# ## Теоретический минимум по методам оптимизации

# %% [markdown]
# 1. Какая форма задача называется задачей целочисленного линейного программирования?
#
# 2. Приведите пример частично целочисленной задачи линейного программирования.
#
# 3. Как записывается математическая постановка транспортной задачи?
#
# 4. Как записывается математическая постановка задачи о назначениях?
#
# 5. Как записывается математическая постановка задачи о рюкзаке?
#
# 6. Что такое план транспортной задачи?
#
# 7. Какие методы поиска опорного плана транспортной задачи вы знаете?
#
# 8. Сколько ненулевых компонент в опорном плане транспортной задачи?
#
# 9. Как формулируется теорема об оптимальном плане для метода потенциалов?
#
# 10. Для решения каких задач используется метод северо-западного угла?
#
# 11. Для решения каких задач  используется метод потенциалов?
#
# 12. Для решения каких задач  используется метод минимального элемента?
#
# 13. Какая модель транспортной задачи называется открытой?
#
# 14.  Какая модель транспортной задачи называется закрытой?
#
# 15. Каким образом окрытую задачу можно свести к закрытой?
#
# 16. Что делать, если в закрытой транспортной задаче перевозки от поставщика $A_i$ к потребителю $B_j$ не могут быть осуществлены (стоит блокировка)?
#
# 17. Что делать, если  от поставщика $A_i$ к потребителю $B_j$ должно быть перевезено не менее $a_{ij}$ единиц груза?
